# %%
# For manipulation 
import numpy as np
import pandas as pd 

# for data visualization
import matplotlib.pyplot as plt
import seaborn as sns 

# for interactivity
from ipywidgets import interact

# %%
# Lets read dataset
data = pd.read_csv("Data.csv")
data.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
# Lets check the shape of the dataset
print("shape of the dataset : ",data.shape)
# Out:
# shape of the dataset :  (1697, 8)

# %%
# Lets check if there is any missing value present or not 
data.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
# Lets check the crops present in the datasets
data["label"].value_counts()
# Out:
# rice          139
# Soyabeans     130
# banana        130
# beans         125
# cowpeas       122
# orange        122
# maize         119
# coffee        110
# peas          100
# groundnuts    100
# mango         100
# grapes        100
# watermelon    100
# apple         100
# cotton        100
# Name: label, dtype: int64

# %%
# Lets check summary all crops

print("Avaerage Ratio of Nitrogen in the soil : {0:.2f}".format(data['N'].mean()))
print("Avaerage Ratio of Phosphorus in the soil : {0:.2f}".format(data['P'].mean()))
print("Avaerage Ratio of Potassium in the soil : {0:.2f}".format(data['K'].mean()))
print("Avaerage Tempreature  in  Celsius : {0:.2f}".format(data['temperature'].mean()))
print("Avaerage Humidity  in  % : {0:.2f}".format(data['humidity'].mean()))
print("Avaerage Ph value of the Soil : {0:.2f}".format(data['ph'].mean()))
print("Avaerage Rainfall  in  Celsius in mm: {0:.2f}".format(data['rainfall'].mean()))
# Out:
# Avaerage Ratio of Nitrogen in the soil : 52.65
# Avaerage Ratio of Phosphorus in the soil : 58.13
# Avaerage Ratio of Potassium in the soil : 52.03
# Avaerage Tempreature  in  Celsius : 24.71
# Avaerage Humidity  in  % : 65.85
# Avaerage Ph value of the Soil : 6.44
# Avaerage Rainfall  in  Celsius in mm: 99.36

# %%
 # Lets check the summary statistics for each of the crops 
    
@interact
def summary(crops = list(data["label"].value_counts().index)):
        x = data[data['label'] == crops] 
        print("-----------------------------")
        print("Stastics for Nitrogen")
        print("Minimum Nitrogen Required :",x['N'].min())
        print("Average Nitrogen Required :",x['N'].mean())
        print("Maxmimum Nitrogen Required :",x['N'].max())
        print("-----------------------------")
        print("Stastics for Phosphorous")
        print("Minimum Phosphorous Required :",x['P'].min())
        print("Average Phosphorous Required :",x['P'].mean())
        print("Maxmimum Phosphorous Required :",x['P'].max())
        print("-----------------------------")
        print("Stastics for Potassium")
        print("Minimum Potassium Required :",x['N'].min())
        print("Average Potassium Required :",x['N'].mean())
        print("Maxmimum Potassium Required :",x['N'].max())
        print("-----------------------------")
        print("Stastics for Temperature")
        print("Minimum Temperature Required :{0:.2f}".format(x['temperature'].min()))
        print("Average Temperature Required :{0:.2f}".format(x['temperature'].mean()))
        print("Maxmimum Temperature Required :{0:.2f}".format(x['temperature'].max()))
        print("-----------------------------")
        print("Stastics for Humidty")
        print("Minimum Humidty Required :{0:.2f}".format(x['humidity'].min()))
        print("Average Humidty Required :{0:.2f}".format(x['humidity'].mean()))
        print("Maxmimum Humidty Required :{0:.2f}".format(x['humidity'].max()))
        print("-----------------------------")
        print("Stastics for Ph value")
        print("Minimum Ph value Required :{0:.2f}".format(x['ph'].min()))
        print("Average Ph value Required :{0:.2f}".format(x['ph'].mean()))
        print("Maxmimum Ph value Required :{0:.2f}".format(x['ph'].max()))
        print("-----------------------------")
        print("Stastics for Rainfall")
        print("Minimum Rainfall Required :{0:.2f}".format(x['rainfall'].min()))
        print("Average Rainfall Required :{0:.2f}".format(x['rainfall'].mean()))
        print("Maxmimum Rainfall Required :{0:.2f}".format(x['rainfall'].max()))
        print("-----------------------------")
# Out:
# interactive(children=(Dropdown(description='crops', options=('rice', 'Soyabeans', 'banana', 'beans', 'cowpeas'…

# %%
## Lets compare the Average Requirement for each crops with orange condtions
@interact
def compare(conditions= ['N','P','K','temperature','ph','humidity','rainfall']):
    print("Average value for",conditions,"is {0:.2f}".format(data[conditions].mean()))
    print("------------------------------------------------")
    print("Rice : {0:.2f}".format(data[(data['label'] == 'rice')][conditions].mean()))
    print("Soyabeans : {0:.2f}".format(data[(data['label'] == 'Soyabeans')][conditions].mean()))
    print("banana : {0:.2f}".format(data[(data['label'] == 'banana')][conditions].mean()))
    print("beans : {0:.2f}".format(data[(data['label'] == 'beans')][conditions].mean()))
    print("cowpeas : {0:.2f}".format(data[(data['label'] == 'cowpeas')][conditions].mean()))
    print("orange : {0:.2f}".format(data[(data['label'] == 'orange')][conditions].mean()))
    print("maize : {0:.2f}".format(data[(data['label'] == 'maize')][conditions].mean()))
    print("coffee : {0:.2f}".format(data[(data['label'] == 'coffee')][conditions].mean()))
    print("peas : {0:.2f}".format(data[(data['label'] == 'peas')][conditions].mean()))
    print("goundnuts : {0:.2f}".format(data[(data['label'] == 'groundnuts')][conditions].mean()))
    print("mango : {0:.2f}".format(data[(data['label'] == 'mango')][conditions].mean()))
    print("grapes : {0:.2f}".format(data[(data['label'] == 'grapes')][conditions].mean()))
    print("watermelons : {0:.2f}".format(data[(data['label'] == 'watermelons')][conditions].mean()))
    print("apple : {0:.2f}".format(data[(data['label'] == 'apple')][conditions].mean()))
    print("cotton : {0:.2f}".format(data[(data['label'] == 'cotton')][conditions].mean()))
# Out:
# interactive(children=(Dropdown(description='conditions', options=('N', 'P', 'K', 'temperature', 'ph', 'humidit…

# %%
## Lets make this function more interactive

@interact
def compare(conditions = ['N','P','K','temperature','ph','humidity','rainfall']):
    print("Crops which require greater than average",conditions,'\n')
    print(data[data[conditions] > data[conditions].mean()]['label'].unique())
    print("------------------------------------------------------------")
    print("Crops which require less than average",conditions,'\n')
    print(data[data[conditions] <= data[conditions].mean()]['label'].unique())
# Out:
# interactive(children=(Dropdown(description='conditions', options=('N', 'P', 'K', 'temperature', 'ph', 'humidit…

# %%
plt.subplot(2,4,1)
sns.distplot(data['N'], color = 'darkblue')
plt.xlabel("Ratio of Nitrogen",fontsize = 8)
plt.grid()
plt.subplot(2,4,2)
sns.distplot(data['P'], color = 'blue')
plt.xlabel("Ratio of Phosphorous",fontsize = 8)
plt.grid()
plt.subplot(2,4,3)
sns.distplot(data['K'], color = 'lightblue')
plt.xlabel("Ratio of Pottasium",fontsize = 8)
plt.grid()
plt.subplot(2,4,4)
sns.distplot(data['temperature'], color = 'black')
plt.xlabel("Ratio of temperature",fontsize = 8)
plt.grid()
plt.subplot(2,4,5)
sns.distplot(data['humidity'], color = 'red')
plt.xlabel("Ratio of humidity",fontsize = 8)
plt.grid()
plt.subplot(2,4,6)
sns.distplot(data['ph'], color = 'orange')
plt.xlabel("Ratio of ph",fontsize = 8)
plt.grid()
plt.subplot(2,4,7)
sns.distplot(data['rainfall'], color = 'grey')
plt.xlabel("Ratio of rainfall",fontsize = 8)
plt.grid()


plt.suptitle("Distribution for Agricultural conditions", fontsize = 20)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
## Lets find out some Intresting facts

print("Some Intresting Patterns")
print("-------------------------------------------")
print("Crops which requires very high Ratio of Nitrogen Content Soil :",data[data['N'] > 120]['label'].unique())
print("Crops which requires very high Ratio of Phosphorous Content Soil :",data[data['P'] > 100]['label'].unique())
print("Crops which requires very high Ratio of Potassium Content Soil :",data[data['K'] > 200]['label'].unique())
print("Crops which requires very high Rainfall :",data[data['rainfall'] > 200]['label'].unique())
print("Crops which requires very low temperature :",data[data['temperature'] < 10]['label'].unique())
print("Crops which requires very high temperature:",data[data['temperature'] > 40]['label'].unique())
print("Crops which requires very low humidity :",data[data['humidity'] < 20]['label'].unique())
print("Crops which requires very high Humidity :",data[data['humidity'] > 70]['label'].unique())
print("Crops which requires very low ph value :",data[data['ph'] > 4]['label'].unique())
print("Crops which requires very high ph value :",data[data['ph'] > 9]['label'].unique())
# Out:
# Some Intresting Patterns
# -------------------------------------------
# Crops which requires very high Ratio of Nitrogen Content Soil : ['cotton']
# Crops which requires very high Ratio of Phosphorous Content Soil : ['grapes' 'apple']
# Crops which requires very high Ratio of Potassium Content Soil : ['grapes' 'apple']
# Crops which requires very high Rainfall : ['rice']
# Crops which requires very low temperature : ['grapes']
# Crops which requires very high temperature: ['grapes']
# Crops which requires very low humidity : ['Soyabeans' 'beans']
# Crops which requires very high Humidity : ['rice' 'maize' 'cowpeas' 'banana' 'grapes' 'watermelon' 'apple' 'orange'
#  'cotton']
# Crops which requires very low ph value : ['rice' 'maize' 'Soyabeans' 'beans' 'peas' 'groundnuts' 'cowpeas' 'banana'
#  'mango' 'grapes' 'watermelon' 'apple' 'orange' 'cotton' 'coffee']
# Crops which requires very high ph value : ['groundnuts']

# %%
## Lets understand which crops can only be drawn in summer season, winter season and rainy season

print("Summer Crops")
print(data[(data['temperature'] > 30) & (data['humidity'] < 70)]['label'].unique())
print("-------------------------------------------------------------")
print("Winter Crops")
print(data[(data['temperature'] > 20) & (data['humidity'] < 40)]['label'].unique())
print("-------------------------------------------------------------")
print("Rainy Crops")
print(data[(data['rainfall'] > 200) & (data['humidity'] > 70)]['label'].unique())
print("-------------------------------------------------------------")
# Out:
# Summer Crops
# ['peas' 'groundnuts' 'mango']
# -------------------------------------------------------------
# Winter Crops
# ['Soyabeans' 'beans' 'peas']
# -------------------------------------------------------------
# Rainy Crops
# ['rice']
# -------------------------------------------------------------

# %%
from sklearn.cluster import KMeans

# Removing the label column
x = data.drop(['label'],axis = 1)

# Selecting all the values of the data 
x = x.values

# checking shape
print(x.shape)
# Out:
# (1697, 7)

# %%
## Lets determine optimum Number of cluster within the Dataset 

plt.rcParams['figure.figsize'] = (10,4)

wcss = []
for i in range(1,11):
    km = KMeans(n_clusters = i , init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0 )
    km.fit(x)
    wcss.append(km.inertia_)
    
# Lets plot the result 
plt.plot(range(1,11),wcss)
plt.title("The Elbow Method ",fontsize = 20)
plt.xlabel('No of clusters')
plt.ylabel('wcss')
plt.show()

# %%
# Lets implement the K Means algorithm to perform clustering analysis
km = KMeans(n_clusters = 4, init = "k-means++", max_iter = 300,n_init = 10, random_state = 0 )
y_means = km.fit_predict(x)

# Lets find out the Results
a = data['label']
y_means = pd.DataFrame(y_means)
z = pd.concat([y_means, a], axis = 1)
z = z.rename(columns = {0:'cluster'})

# Lets check the clusters of each Crops
print("Lets check the Result after applying the  K means Clustering analysis \n")
print("Crops in First Cluster : ", z[z['cluster'] == 0]['label'].unique())
print("-------------------------------------------------")
print("Crops in First Cluster : ", z[z['cluster'] == 1]['label'].unique())
print("-------------------------------------------------")
print("Crops in First Cluster : ", z[z['cluster'] == 2]['label'].unique())
print("-------------------------------------------------")
print("Crops in First Cluster : ", z[z['cluster'] == 3]['label'].unique())
print("-------------------------------------------------")
# Out:
# Lets check the Result after applying the  K means Clustering analysis
#
# Crops in First Cluster :  ['maize' 'Soyabeans' 'beans' 'peas' 'groundnuts' 'cowpeas' 'mango'
#  'orange']
# -------------------------------------------------
# Crops in First Cluster :  ['maize' 'banana' 'watermelon' 'cotton' 'coffee' 'rice']
# -------------------------------------------------
# Crops in First Cluster :  ['grapes' 'apple']
# -------------------------------------------------
# Crops in First Cluster :  ['rice' 'peas' 'coffee']
# -------------------------------------------------
